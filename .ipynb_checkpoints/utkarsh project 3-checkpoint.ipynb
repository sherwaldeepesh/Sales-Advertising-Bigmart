# %%
#Task1(Part 1)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn import metrics
import statsmodels.api as sm

# %% [markdown]
# Libraries imported, will be used in this program.

# %%
df_marketing = pd.read_csv('SalesBasedOnAdvertising.csv')

# %%
#Task1(Part 2)
df_marketing.shape
# Out:
# (204, 5)

# %% [markdown]
# Bigmart Data have 204 rows and 5 columns

# %%
#Task1(Part 3)
df_marketing.head()
# Out:
#    Sno     TV  radio  newspaper  sales
# 0    1  219.0    NaN       34.5   48.9
# 1    2  230.1   37.8       69.2   22.1
# 2    3   44.5   39.3       45.1   10.4
# 3    4   17.2   45.9       69.3    9.3
# 4    5  151.5   41.3       58.5   18.5

# %% [markdown]
# This is the basic view of dataset showing all 5 columns in the datbase. Here Tv, radio and newspaper advertising price is in thousands and sales price is in lacs.

# %%
df_marketing.describe()
# Out:
#               Sno          TV       radio   newspaper       sales
# count  204.000000  204.000000  203.000000  204.000000  204.000000
# mean   102.500000  146.602451   23.122167   30.712255   14.020588
# std     59.033889   86.062496   14.810692   21.731852    5.905251
# min      1.000000    0.000000    0.000000    0.300000    0.000000
# 25%     51.750000   72.700000    9.950000   12.875000   10.250000
# 50%    102.500000  149.750000   22.300000   26.050000   12.900000
# 75%    153.250000  218.625000   36.400000   45.100000   17.400000
# max    204.000000  296.400000   49.600000  114.000000   48.900000

# %% [markdown]
# Basic Statistics of dataset

# %%
df_marketing.dtypes
# Out:
# Sno            int64
# TV           float64
# radio        float64
# newspaper    float64
# sales        float64
# dtype: object

# %% [markdown]
# All the Columns and there datatypes

# %%
#Task 1(Part 4)
df_marketing.isnull().sum()
# Out:
# Sno          0
# TV           0
# radio        1
# newspaper    0
# sales        0
# dtype: int64

# %% [markdown]
# there is null only in radio column

# %%
df_marketing[df_marketing['sales']==0]
# Out:
#      Sno    TV  radio  newspaper  sales
# 97    98   0.0   18.0       67.0    0.0
# 121  122  69.4    3.0       34.0    0.0

# %% [markdown]
# Looking for the columns where there is 0 in sales column

# %%
df_marketing=df_marketing.drop((df_marketing[df_marketing['sales']==0]).index)

# %% [markdown]
# Dropping the rows where there is 0 in sales column

# %%
df_marketing['radio'] = df_marketing['radio'].fillna(df_marketing['radio'].mean())

# %% [markdown]
# Handling null values with mean

# %%
df_marketing['sales'] = df_marketing['sales']*100

# %% [markdown]
# setting sales column on the scale of thousand

# %%
#Task 1(Part 5)
df_marketing.shape

df_marketing.head()
# Out:
#    Sno     TV      radio  newspaper   sales
# 0    1  219.0  23.247761       34.5  4890.0
# 1    2  230.1  37.800000       69.2  2210.0
# 2    3   44.5  39.300000       45.1  1040.0
# 3    4   17.2  45.900000       69.3   930.0
# 4    5  151.5  41.300000       58.5  1850.0

# %% [markdown]
# nan value is updated with mean of entire column and the fields with 0 in sales column are deleted.

# %%
df_marketing.describe()
# Out:
#               Sno          TV       radio   newspaper        sales
# count  202.000000  202.000000  202.000000  202.000000   202.000000
# mean   102.425743  147.710396   23.247761   30.516337  1415.940594
# std     59.310021   85.689200   14.774545   21.687071   576.572784
# min      1.000000    0.700000    0.000000    0.300000   160.000000
# 25%     51.250000   74.800000   10.025000   12.825000  1032.500000
# 50%    102.500000  150.650000   22.873881   25.750000  1290.000000
# 75%    153.750000  218.875000   36.450000   44.900000  1740.000000
# max    204.000000  296.400000   49.600000  114.000000  4890.000000

# %% [markdown]
# Values of sales that were on the scale of Lacs are now set on the scale of thousands.

# %%
df_marketing.dtypes
# Out:
# Sno            int64
# TV           float64
# radio        float64
# newspaper    float64
# sales        float64
# dtype: object

# %%
#Task 2(Part 1)
fig = plt.figure(figsize = (5,12))
ax1 = plt.subplot(411)
ax1 = plt.boxplot(df_marketing['TV'])
ax1 = plt.title('Boxplot of Marketing[TV]')

ax2 = plt.subplot(412)
ax2 = plt.boxplot(df_marketing['radio'])
ax1 = plt.title('Boxplot of Marketing[Radio]')

ax3 = plt.subplot(413)
ax3 = plt.boxplot(df_marketing['newspaper'])
ax1 = plt.title('Boxplot of Marketing[Newspaper]')

ax4 = plt.subplot(414)
ax4 = plt.boxplot(df_marketing['sales'])
ax1 = plt.title('Boxplot of Marketing[Sales]')

# %% [markdown]
# In advertisement tv and radio have uniformly distributed data but newspaper have some outliers, so there are some outliers in sales alsoBox plots and distribution of advertising and sales with line plot

# %%
#Task 2(Part 2)
fig = plt.figure(figsize = (13,6))
ax1 = plt.subplot(211)
ax1 = plt.title('Boxplot of Advertising[TV,Radio,Newspaper] and Sales')
ax1 = plt.boxplot([df_marketing['sales'],df_marketing['TV'],df_marketing['radio'],df_marketing['newspaper']])
ax1 = plt.xticks([1,2,3,4],['Sales','TV','Radio','Newspaper'])


ax2 = plt.subplot(212)
ax2 = plt.title('Plot of Advertising[TV,Radio,Newspaper] and Sales', pad = 2)
ax2 = plt.plot(df_marketing['sales'],label = 'Sales')
ax2 = plt.plot(df_marketing['TV'],label = 'TV')
ax2 = plt.plot(df_marketing['radio'],label = 'Radio')
ax2 = plt.plot(df_marketing['newspaper'],label = 'Newspaper')
ax2 = plt.ylabel('Amount thousands for advt & lakhs for sales ')
plt.legend(loc = 'best')

# %% [markdown]
# Box plots and distribution of advertising and sales with line plot

# %% [markdown]
# #Task 3(Part 1)
# To find the marketing expenses based on dependent and independent variables from the given dataset we can conclude that tv is one of the most important factor for marketing and it will definately effect our prediction then there will be newspaer and then radio.

# %%
#Task 3(Part 2)
sns.distplot(df_marketing['sales'])
# Out:
# C:\Users\deepe\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\deepe\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# This plot shows that probabilty of sales is highest at level of 1300 thousand at peek level and range from 700 to 1800 holds a good probability of achieving the sales other sales in terms of 30, 40 or 50 lacs are not normal to achieve

# %%
#Task 4(Part 1)
x1 = df_marketing['TV'].values.reshape(-1,1)
y1 = df_marketing['sales']
plt.scatter(x1,y1)
plt.xlabel('Tv advertising amount(in thousands)')
plt.ylabel('Sales amount(in lakhs)')
plt.title('Advertising[TV] and Sales')
# Out:
# Text(0.5,1,'Advertising[TV] and Sales')

# %% [markdown]
# This scatter plot showing a pattern with Advertising on Tv with Sales as incresed, it shows that as the amount increased on advertisement as the sales increase

# %%
#Task 4(Part 2)
fig = plt.figure(figsize = (20,5))
ax3 = plt.subplot(131)
x1 = df_marketing['TV'].values.reshape(-1,1)
y1 = df_marketing['sales']
plt.scatter(x1,y1,color = 'seagreen')
plt.xlabel('Tv advertising amount(in thousands)')
plt.ylabel('Sales amount(in lakhs)')
plt.title('Advertising[TV] and Sales')

ax3 = plt.subplot(132)
x2 = df_marketing['newspaper'].values.reshape(-1,1)
y2 = df_marketing['sales']
plt.scatter(x2,y2,color = 'darkgreen')
plt.xlabel('Newspaper advertising amount(in thousands)')
plt.ylabel('Sales amount(in lakhs)')
plt.title('Advertising[Newspaper] and Sales')

ax3 = plt.subplot(133)
x3 = df_marketing['radio'].values.reshape(-1,1)
y3 = df_marketing['sales']
plt.scatter(x3,y3,color = 'black')
plt.xlabel('Radio advertising amount(in thousands)')
plt.ylabel('Sales amount(in lakhs)')
plt.title('Advertising[Radio] and Sales')
# Out:
# Text(0.5,1,'Advertising[Radio] and Sales')

# %% [markdown]
# Advertising on TV is showing increasing sales with increase in advertising on TV but on newspaper it showing a constant pattern but for lower market the newspaper and Radio are best that they can achieve their values for the low valued products for Radio it also shows increasing pattern with sales

# %%
#Task 4(Part 3)
sns.pairplot(df_marketing,vars = ['TV','radio','newspaper'],hue = 'sales')

# %% [markdown]
# Here we can see the combination of tv and radio or radio and newspaper also showing a great impact on sales

# %%
#Task 5(Part 1)
df_marketing['TotalAdvt'] = sum([df_marketing['TV'],df_marketing['radio'],df_marketing['newspaper']])

# %%
#Task 5(Part 2)
x = df_marketing['TotalAdvt'].values.reshape(-1,1)
y = df_marketing['sales']

simple_model = linear_model.LinearRegression()

simple_model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# Linear model with one column is an example of simple linear model in this here we observe that how the three of advertisement if combined than how they effect on sales

# %%
simple_model.intercept_
# Out:
# 412.94534013284647

# %%
simple_model.coef_
# Out:
# array([4.9782741])

# %%
simple_model.score(x,y)
# Out:
# 0.6411334702839222

# %%
#Task 5(Part 3)
#4.9782741*x +412.94534013284647

# %%
#Task 5(Part 4)
simple_model.predict(50000)
# Out:
# array([249326.65016552])

# %%
#Task 6(Part 1)
xm = df_marketing.iloc[:,1:4].values
ym = df_marketing['sales']

multi_model = linear_model.LinearRegression()

multi_model.fit(xm,ym)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# In multiple linear regression here we observe the dependency of every column having advertisement investment affects on sales

# %%
multi_model.coef_
# Out:
# array([ 4.68636807, 18.76042293,  0.14346244])

# %%
multi_model.intercept_
# Out:
# 283.19952964638355

# %%
multi_model.score(xm,ym)
# Out:
# 0.7545163072955383

# %%
#Task 6(Part 2)
# 4.68636807*x1+18.76042293*x2+0.14346244*x3+283.19952964638355

# %%
#For Advertising value tv 90000, radio 3000 and newspaper 45000
4.68636807*90000+18.76042293*3000+0.14346244*45000+283.19952964638355
# Out:
# 484793.40441964637

# %%
# for Advertising value tv 290000 and newspaper 80000
4.68636807*290000+18.76042293*0+0.14346244*80000+283.19952964638355
# Out:
# 1370806.9350296466

# %%
#Task 6 (Part 3)
#For Advertising value tv 90000, radio 3000 and newspaper 45000
multi_model.predict(np.array([90000,3000,45000]).reshape(1,-1))
# Out:
# array([484793.40474545])

# %%
# for Advertising value tv 290000 and newspaper 80000
multi_model.predict(np.array([290000,0,80000]).reshape(1,-1))
# Out:
# array([1370806.93610348])

# %% [markdown]
# Both the values calculated in mathematical way or by model predict both are approximately equal

# %%
#Task 7(Part 1)
simple_y = simple_model.predict(x)

multi_y = multi_model.predict(xm)

# %%
#Task 7(Part 2)
simple_mse = metrics.mean_squared_error(y,simple_y)

multi_mse = metrics.mean_squared_error(ym,multi_y)

# %%
simple_mse
# Out:
# 118709.62154247984

# %%
multi_mse
# Out:
# 81203.6616478349

# %% [markdown]
# #Task 7(Part 3)
# Here we get an obsevervation that multiple regression model have less value of error this says that better use of multiple over simple model.

# %% [markdown]
# Here observing the r2 score of both the model and we got the comparison of errors also.
